# %%
import pandas as pd
import joblib

# %% [markdown]
# ## CSTR

# %%
X_train = joblib.load("../dados/atv3/X_train_CSTR.pkl")
y_train = joblib.load("../dados/atv3/y_train_CSTR.pkl")
X_test = joblib.load("../dados/atv3/X_test_CSTR.pkl")
y_test = joblib.load("../dados/atv3/y_test_CSTR.pkl")

# %%
results_cstr = pd.read_csv("../dados/atv3/results_gs_CSTR.csv")
results_cstr
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.001483      0.000436         0.000569        0.000128          0.1
# 1        0.001145      0.000062         0.000500        0.000043          0.1
# 2        0.001177      0.000133         0.000530        0.000121          0.5
# 3        0.001366      0.000327         0.000602        0.000166          0.5
# 4        0.001153      0.000096         0.000475        0.000019          1.0
# 5        0.001164      0.000174         0.000492        0.000045          1.0
# 6        0.001237      0.000171         0.000557        0.000103          1.5
# 7        0.001261      0.000233         0.000547        0.000086          1.5
# 8        0.004077      0.003398         0.000551        0.000035          NaN
# 9        0.004186      0.000936         0.000633        0.000128          NaN
# 10       0.002050      0.000060         0.000512        0.000078          NaN
# ...
